# %% [markdown]
# # Práctica 2. Hadoop MapReduce.

# %% [markdown]
# ## SESION 1. Manejo de un cluster Hadoop 3. Gestión HDFS y YARN.
#
# En esta práctica utilizaremos contenedores Docker para trabajar sobre un cluster Hadoop.
#
# Debido a que la instalación y despliegue de un cluster Hadoop no es objetivo formativo de esta asignatura, los profesores proporcionan una máquina virtual Ubuntu (formato .OVA) que contiene una instalación completa de un cluster Hadoop 3 haciendo uso de contenedores Docker. La máquina virtual la puedes descargar en el siguiente [enlace](https://www.ditec.um.es/~jcebrian/ppd/PPD_Ubuntu_2204_Apartado2.ova).
#
# Tomando como punto de partida esta máquina virtual, realizaremos diversas actividades prácticas para familiarizarnos con el manejo del sistema de ficheros HDFS y la gestión de recursos basada en YARN.
#
# **ENTREGA OBLIGATORIA**
#
# Una de las actividades de la Tarea 2 de la asignatura (se publicará próximamente) requiere que el alumno demuestre haber seguido los pasos de este notebook. Con este propósito, se solicita generar una memoria que incluya capturas de pantalla, explicaciones y todos los detalles que el alumno considere necesarios para demostrar que ha realizado los pasos y entendido las preguntas y/o tareas que se formulan en las siguientes secciones.
#
# **NOTA IMPORTANTE**
#
# El documento no puede consistir en una mera secuencia de imágenes. Es necesario describir los comandos ejecutados, interpretar la información que se obtiene y razonar la manera de resolver las tareas propuestas.

# %% [markdown]
# ---
# ### APARTADO 1. Primeros pasos. Descripción del escenario.
#
# 1. Descarga la máquina virtual y procede a su realizar su importación. Recomendamos usar VirtualBox, aunque también puedes emplear VMWare o cualquier software de virtualización que soporte la importación de imágenes en formato OVA.
#
# 2. Inicia sesión. El usuario es `ppd` y la contraseña `ppd123`.
#
# 3. La máquina virtual ya ha sido configurada para que, haciendo uso de contenedores Docker, se implemente un cluster de 5 máquinas: 1 NameNode/ResourceManager y 4 DataNodes/NodeManagers.
#
# <div style="text-align: center;">
# <img src="......
# " width="500"/>
# </div>

# %% [markdown]
# ##### 1.1.5 Acceso a los interfaces web de los demonios
#
# Los diferentes servicios de Hadoop ofrecen una interfaz web de control. Abre un navegador y comprueba los siguientes enlaces:
#
# - http://localhost:9870 interfaz web del HDFS.
# - http://localhost:8088 interfaz web de YARN.

# %% [markdown]
# ---
# ### APARTADO 2: Inicio del cluster Hadoop con contenedores Docker
#
# Vamos a iniciar nuestro cluster, formado por 1 NameNode/ResourceManager y 4 DataNodes/NodeManagers. Analiza la RAM disponible y si tienes poca RAM libre, puedes iniciar solo 3 de estos últimos.
#
# 1. Inicia el NameNode/ResourceManager (puedes ajustar las especificaciones de CPU y memoria en función del número de cores y RAM del equipo)
#
# ```bash
# docker container run -d --name namenode --network=hadoop-cluster --hostname namenode --net-alias resourcemanager --cpus=1 --memory=3072m --expose=8000-10000 -p 9870:9870 -p 8088:8088 -p 8888:8888 -p 4040:4040 namenode-image /inicio.sh
# ```
#
# 2. Inicia los 4 DataNodes/NodeManagers (puedes ajustar las especificaciones de cpu y memoria en función del número de cores y RAM del equipo)
#
# ```bash
# for i in {1..4}; do docker container run -d --name datanode$i --network=hadoop-cluster --hostname datanode$i --cpus=1 --memory=3072m --expose=8000-10000 --expose=50000-50200 datanode-image /inicio.sh; done
# ```
#
# 3. Los contenedores en ejecución pueden consultarse con el comando `docker container ps`. Comprueba que están ejecutándose los 5 contenedores.
#
# 4. Conéctate al **NameNode/Resource Manager** ejecutando:
#
# ```bash
# docker container exec -ti namenode /bin/bash
# ```
#
#    y una vez dentro de contenedor, cambiar al usuario `hdadmin`
#
# ```bash
# su - hdadmin
# ```
#
# 5. Todos los demonios de Hadoop se configuran, principalmente, mediante cuatro ficheros, localizados en `$HADOOP_HOME/etc/hadoop/`, en los que se pueden indicar un gran número de propiedades (véase http://hadoop.apache.org/docs/stable3/hadoop-project-dist/hadoop-common/ClusterSetup.html para más información):
#
# - `core-site.xml`: configuración principal, valores por defecto en http://hadoop.apache.org/docs/stable3/hadoop-project-dist/hadoop-common/core-default.xml
#
# - `hdfs-site.xml`: configuración del HDFS, valores por defecto en http://hadoop.apache.org/docs/stable3/hadoop-project-dist/hadoop-hdfs/hdfs-default.xml
#
# - `yarn-site.xml`: configuración del YARN, valores por defecto en http://hadoop.apache.org/docs/stable3/hadoop-yarn/hadoop-yarn-common/yarn-default.xml
#
# - `mapred-site.xml`: configuración del MapReduce, valores por defecto en http://hadoop.apache.org/docs/stable3/hadoop-mapreduce-client/hadoop-mapreduce-client-core/mapred-default.xml
#
# Localiza estos ficheros y revisa su contenido. Te será fácil interpretar los parámetros de configuración ya que estos se encuentran comentados. ¿Qué opciones de configuración regulan las características de funcionamiento HDFS y MapReduce vistas en clase de teoría?
#
# 5. Los servicios que se ejecutan dentro de cada contenedor que pertenecen a Hadoop son normalmente servicios java, por lo que con la utilidad `jps` se puede comprobar cuáles tenemos en ejecución. Si no tenemos los servicios que se esperan, puede haber un error en la ejecución o en cómo se construyó el contenedor. Como usuario `hdadmin` (**ESTO ES MUY IMPORTANTE**), ejecuta el comando `jps -l`. Observa la información que aparece. ¿Cuántos servicios se encuentran activos? ¿Qué cometido tiene cada uno?
#
# 6. Además de verificar que los servicios están operativos, podemos comprobar que todo va bien interactuando directamente con cada servicio:
#
# ```bash
# hdfs dfsadmin -report
# yarn node -list
# ```
#
#   Analiza la información que devuelve cada uno de los dos comandos anteriores. ¿Qué conclusiones puedes extraer? ¿Qué parte es la más relevante a la hora de determinar si el cluster Hadoop está funcionando correctamente?
#
#
# 7. Los diferentes servicios de Hadoop ofrecen una interfaz web de control. Concretamente, los demonios que implementan la funcionalidad de NameNode y ResourceManagner ofrecen una interfaz web que podemos acceder a través de los siguientes enlaces:
#
# - http://localhost:9870 interfaz web del HDFS.
# - http://localhost:8088 interfaz web de YARN.
#
# Abre el navegador y comprueba que puedes acceder a ambas interfaces web. Analiza la información que aparece y compárala con la obtenida en el punto anterior mediante los comandos `hdfs dfsadmin -report` y `yarn node -list`.
#
# 8. Para salir del contenedor hay que escribir `exit` dos veces: una saldrá del usuario `hdadmin` de vuelta hacia `root`, y el último `exit` saldrá del `exec` hacia el contenedor (aunque el contenedor continúa ejecutándose en segundo plano):
#
# ```bash
# hdadmin@namenode:~$ exit
# logout
# root@namenode:/# exit
# exit
# ppd@ppd-VirtualBox:dir$
# ```
#
# 9. Conéctate a un **Datanode/NodeManager** y repite los pasos [4-6] anteriormente descritos. Comparado con el NameNode/Resource Manager, ¿qué nueva información obtienes en un DataNode/NodeManager?
#
# <br>
#
# **Por seguridad, antes de apagar la máquina virtual, debes PARAR TODOS los contenedores**. Para ello bastará con ejecutar el comando `docker container stop` y el nombre del contenedor. También es posible parar todos los contenedores a la vez:
#
# ```bash
# docker container stop namenode datanode{1..4}
# ```
#
# Cuando detienes los contenedores, si ejecutas el comando `docker container ps` verás que devuelve una lista vacía. Esto se debe a que este comando sólo muestra los contenedores en ejecución. Si queremos ver todos los contenedores que se ejecutaron en algún momento y que no han sido eliminados, podemos hacer `docker container ps -a`.
#
# Cuando quieras volver a iniciar los contenedores, simplemente debes usar el comando `docker container start` y el nombre del contenedor. Como puedes observar en el siguiente comando, se puede indicar el nombre de varios contenedores:
#
# ```bash
# docker container start namenode datanode{1..4}
# ```
#
# <span style="color: red;">**RECUERDA, por seguridad, SIEMPRE debes PARAR los contenedores ANTES DE APAGAR la máquina virtual**</span>

# %% [markdown]
# ---
# ### APARTADO 3: Interfaz línea de comandos para acceder al sistema de ficheros HDFS. Creación de directorios y copia de datos.

# %% [markdown]
# ####  3.1 Creación de los directorios de los usuarios en HDFS
#
# Dentro del Namenode, como usuario `hdadmin`, crea directorios en HDFS (dentro de `/user`) para el usuario `hdadmin` y para el usuario local `luser` (que es el que va a ejecutar las tareas MapReduce):
#
# ```bash
# hdfs dfs -mkdir -p /user/hdadmin
# hdfs dfs -mkdir -p /user/luser
# hdfs dfs -chown luser /user/luser
# hdfs dfs -ls /user
# ```
#
# Debemos crear también un directorio `/tmp` y darle los permisos adecuados
#
# ```bash
# hdfs dfs -mkdir -p /tmp/hadoop-yarn/staging
# hdfs dfs -mkdir -p /tmp/logs
# hdfs dfs -chmod -R 1777 /tmp
# hdfs dfs -chmod -R 1777 /tmp/logs
# ```

# %% [markdown]
# #### 3.2 Copia de ficheros de usuario
#
#
# 1. En el Namenode, conviertete en usuario no privilegiado (haciendo, como root, `su - luser`)
#
# 2. Comprueba que puedes acceder al HDFS ejecutando:
#
# ```bash
# hdfs dfs -ls
# ```
#    (Este comando no debería dar ninguna salida, ya que no tenemos nada en el directorio HOME del usuario `lsuer`)
#
# 3. Descarga de https://umubox.um.es/index.php/s/TDBPLG59W3BrOaD/download unos ficheros de ejemplo que usaremos en esta practica y cópialos al contenedor del NameNode usando:
#
# ```bash
# docker container cp ~/Descargas/libros.tar namenode:/tmp
# ```
#
# 4. Conéctate al NameNode, descomprime el fichero y copia los datos a HDFS
#
# ```bash
# cd /tmp; tar xvf libros.tar
# hdfs dfs -put libros .
# hdfs dfs -ls libros
# ```
#
# 5. Cuando se ejecuta comandos con `hdfs dfs`, el directorio actual es el directorio home del usuario que ejecuta el comando, en este caso, `/user/luser`. Comprueba que, efectivamente, los datos copiados se encuentran en esta ubicación:
#
# ```bash
# hdfs dfs -ls /user/luser
# hdfs dfs -ls libros
# ```
#
# 5. Borra el directorio libros del disco local (`rm -rf /tmp/libros`) y, como root, el fichero `libros.tar`
#
#
# 5. Mira en el interfaz web del HDFS donde se encuentran los bloques correspondientes al fichero **random_words.txt.bz2**. Comprueba que cada bloque tiene 3 réplicas.
#    - Abre el navegador y conéctate al interfaz web del NameNode
#    - Ve al menu "Utilities" -> "Browse the filesystem"
#
#
#    ¿Cuántos bloques se emplean para almacenar el contenido de este fichero? ¿Cuántas replicas tiene cada bloque?

# %% [markdown]
# ---
# ### APARTADO 4. Interfaz Python para acceder al sistema de ficheros HDFS.
#
# #### 4.1 Ejecución del código `filesystem_cat` (ver transparencias tema 2)

# %% [markdown]
# 1. Descarga el fichero `filesystem_cat.py` en el siguiente [enlace](https://raw.githubusercontent.com/fernando-pereniguez/GCID-PPD-2425/refs/heads/main/P2/filesystem_cat.py).
#
# 2. Súbelo al contenedor `namenode` en el directorio del usuario `luser`:
#
# ```bash
# docker cp filessytem_cat.py namenode:/home/luser
# ```
#
# 3. En el `namenode`, como usuario `luser` (`su - luser`):
#
#
# 4. Para ejecutarlo, hay que hacer unos pasos iniciales:
#    - Instalar el paquete `pyarrow`:
#     ```bash
#     pip install pyarrow
#     ```
#
#    - Establecer correctamente la variable de entorno CLASSPATH:
#     ```bash
#     export CLASSPATH=$(hdfs classpath --glob)
#     ```
# <br>
# 5. Comprueba que es capaz de mostrar algún fichero de texto (sin comprimir) que subáis a HDFS, como se hizo en la práctica 1 co los libros, por ejemplo:
#
# ```bash
# python3 filesystem_cat.py hdfs://namenode:9000/fichero/a/mostrar
# ```

# %% [markdown]
# #### 4.2 Tarea: implementa el programa `copy_half_file`

# %% [markdown]
# 1. Basándote en el código anterior y en la plantilla de programa [`copy_half_file.py`](https://raw.githubusercontent.com/fernando-pereniguez/GCID-PPD-2425/refs/heads/main/P2/copy_half_file.py), escribe un programa que copie la mitad inferior del fichero en HDFS a otro fichero en otro directorio del HDFS
#
# 2. Pistas:
#    - Usa `get_file_info()` para obtener la longitud del fichero.
#    - Para moverte a la mitad de un fichero, usa `seek()`.
#    - Para realizar la copia, usa la biblioteca *shutil*.

# %% [markdown]
# ---
# ### APARTADO 5: Prueba de aplicaciones MapReduce simples

# %% [markdown]
# #### 5.1 Aplicación MapReduce para el cálculo de Pi
#
# Vamos a probar nuestra primera aplicación MapReduce haciendo uso de un ejemplo que viene incluido en la instalación Hadoop. Este ejemplo calcula una aproximación del valor de π (pi) utilizando un enfoque de Monte Carlo. El proceso funciona de la siguiente manera:
#
# 1. **Generación de puntos aleatorios**:
#    - Cada *tarea map* genera un conjunto de puntos aleatorios en un cuadrado de 2x2 (con coordenadas entre -1 y 1).
#    - Estos puntos se generan dentro de un círculo inscrito en el cuadrado (de radio 1).
#
# 2. **Conteo de puntos dentro del círculo**:
#    - Para cada punto generado, se verifica si está dentro del círculo (usando la fórmula $ x^2 + y^2 \leq 1 $).
#    - Si el punto está dentro del círculo, se cuenta como un "éxito".
#
# 3. **Cálculo de la proporción**:
#    - La proporción de puntos dentro del círculo respecto al total de puntos generados se usa para aproximar el valor de π.
#    - Dado que el área del círculo es $\pi r^2 $ y el área del cuadrado es $4$, la proporción de puntos dentro del círculo es aproximadamente $\frac{\pi}{4}$.
#    - Por lo tanto, $\pi \approx 4 \times \frac{\text{número de puntos dentro del círculo}}{\text{número total de puntos}}$.
#
# 4. **Agregación de resultados**:
#    - Los resultados de todos las *tareas map* se combinan en la *fase de reducción* para obtener un conteo total de puntos dentro del círculo y un conteo total de puntos generados.
#    - Finalmente, se calcula el valor de π usando la fórmula anterior.

# %% [markdown]
# En el NameNode, **como usuario `hdadmin`**, ejecuta los siguientes comandos para lanzar la aplicación MapReduce que implementa la aproximación de Pi empleando el proceso descrito anteriormente:
#
# ```bash
# export MAPRED_EXAMPLES=$HADOOP_HOME/share/hadoop/mapreduce
# yarn jar $MAPRED_EXAMPLES/hadoop-mapreduce-examples-*.jar pi 16 1000
# ```
#
# Monitoriza la ejecución de esta tarea por medio del interfaz web de Yarn. Explora todas las opciones y menus disponibles e identifica toda la información que resume la ejecución de la tarea MapReduce.
#
#
# ## **Solución de problemas**:
#
# ```bash
# The required MAP capability is more than the supported max container capability in the cluster. Killing the Job. mapResourceRequest: <memory:3840, vCores:1> maxContainerCapability:<memory:3552, vCores:1>
# ```
#
# La cantidad de memoria por contenedor excede la máxima establecida por el sistema. Vamos a limitar la capacidad por contenedor:
#
# Entramos al namenode y editamos el fichero de configuración de Yarn.
#
#
# ```bash
# docker container exec -ti namenode /bin/bash
# su - hdadmin
# cd $HADOOP_HOME/etc/hadoop/
# ```
#
# Edita el fichero yarn-site.xml (por ejemplo con emacs)
#
# ```bash
# emacs yarn-site.xml
# ```
#
# Busca la linea de yarn.scheduler.maximum-allocation-mb y cambia el valor por 3840.
#
# ```bash
#   <property>
#     <!-- Memoria maxima (MB) que un ApplicationMaster puede solicitar al RM (por defecto: 8192 MB) -->
#     <!-- Peticiones mayores lanzan una InvalidResourceRequestException -->
#     <!-- Puedes aumentar o reducir este valor en funcion de la memoria de la que dispongas -->
#     <name>yarn.scheduler.maximum-allocation-mb</name>
#     <value>3840</value>
#     <final>true</final>
#   </property>
# ```
#
# Puedes guardar los cambios con Ctrl-X Ctrl-S y salir con Ctrl-X Ctrl-C.
#
# Reinicia los demonios
#
# ```bash
# yarn --daemon stop nodemanager
# yarn --daemon start nodemanager
# yarn --daemon stop resourcemanager
# yarn --daemon start resourcemanager
# ```
#
# ***********************************
#
# **Función de shuffle no definida.**
#
# ```bash
# 2025-02-23 19:05:53,499 INFO mapreduce.Job: Task Id : attempt_1740333870909_0002_m_000001_2, Status : FAILED
# Container launch failed for container_1740333870909_0002_01_000007 : org.apache.hadoop.yarn.exceptions.InvalidAuxServiceException: The auxService:mapreduce_shuffle does not exist
# ```
#
# Entramos al namenode y editamos el fichero de configuración de Yarn.
#
#
# ```bash
# docker container exec -ti namenode /bin/bash
# su - hdadmin
# cd $HADOOP_HOME/etc/hadoop/
# ```
#
# Edita el fichero yarn-site.xml (por ejemplo con emacs)
#
# ```bash
# emacs yarn-site.xml
# ```
# Añadimos las siguientes líneas.
#
# ```bash
#   <property>
#     <name>yarn.nodemanager.aux-services</name>
#     <value>mapreduce_shuffle</value>
#   </property>
#   <property>
#     <name>yarn.nodemanager.aux-services.mapreduce_shuffle.class</name>
#     <value>org.apache.hadoop.mapred.ShuffleHandler</value>
#   </property>
# ```
#
# Puedes guardar los cambios con Ctrl-X Ctrl-S y salir con Ctrl-X Ctrl-C.
#
# Reinicia los demonios
#
# ```bash
# yarn --daemon stop nodemanager
# yarn --daemon start nodemanager
# yarn --daemon stop resourcemanager
# yarn --daemon start resourcemanager
# ```

# %% [markdown]
# #### 5.2 Aplicación WordCount
#
# Ahora vamos a probar una aplicación MapReduce que implementa el ejemplo de conteo de palabras estudiado en clase de teoría. Revisa las transparencias para recordar como funciona.
#
# 1. Descarga el código Java del wordcount en el siguiente
# [enlace](https://github.com/dsevilla/tcdm-public/raw/21-22/practicas/p1/wordcount.tgz).
#
# 2. Cópialo en el NameNode
#
# ```bash
# docker cp ~/Downloads/wordcount.tgz namenode:/home/luser
# ```
#
# 3. Conéctate al NameNode y, como usuario `luser`, descomprímelo y compílalo usando maven:
#
# ```bash
# cd; tar xvzf wordcount.tgz
# cd wordcount
# mvn package
# ```
#
# 4. Ejecútalo con el comando Yarn:
#
# ```bash
# yarn jar target/wordcount*.jar libros/p* wordcount-out
# ```
#
#   Comprueba en el interfaz web de Yarn la ejecución de esta tarea.
#
# 5. Trae los ficheros de salida del HDFS al disco local del NameNode:
#
# ```bash
# hdfs dfs -get wordcount-out
# ```
#
# 6. Analiza la salida que ha generado la ejecución de la tarea MapReduce. ¿Porqué se generan diversos ficheros?
#
# 7. Analiza la información de salida que devuelve el comando yarn y constrastala con la información disponible a través de la web YARN. ¿Cuántos splits se han generado? ¿Cuántas tareas map se han ejecutado? ¿Cuántas tareas reduce? ¿Falló la ejecución de alguna tareas map y o reduce? ¿Cómo ha repartido la función de particionado los pares (clave,valor) intermedios?
